# %% [markdown]
# 1. Apply the following threshold method to image ca[.ext]
#
# -Binary inverse
#
# -Truncate
#
# -Tozero
#
# -Tozero Inverse

# %%
import cv2 as cv
import matplotlib.pyplot as plt

img = cv.imread('../essential/assets/ca2.jpg')
imgGray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)

maxval= 255

plt.figure(figsize=(15,25))
plt.subplot(631)
imgRGB = cv.cvtColor(imgGray,cv.COLOR_GRAY2RGB)
plt.title("Original")
plt.imshow(imgRGB)
plt.axis('off')

thresh =50
ret,imgThresh= cv.threshold(img,thresh,maxval,cv.THRESH_BINARY)
plt.subplot(634)
imgRGB = imgThresh[:,:,::-1]
plt.title(f'BINARY 1 = {thresh}')
plt.imshow(imgRGB)
plt.axis('off')

thresh =150
ret,imgThresh= cv.threshold(img,thresh,maxval,cv.THRESH_BINARY)
plt.subplot(635)
imgRGB = imgThresh[:,:,::-1]
plt.title(f'BINARY 2 = {thresh}')
plt.imshow(imgRGB)
plt.axis('off')

thresh =250
ret,imgThresh= cv.threshold(img,thresh,maxval,cv.THRESH_BINARY)
plt.subplot(636)
imgRGB = imgThresh[:,:,::-1]
plt.title(f'BINARY 3 = {thresh}')
plt.imshow(imgRGB)
plt.axis('off')

thresh =50
ret,imgThresh= cv.threshold(img,thresh,maxval,cv.THRESH_BINARY_INV)
plt.subplot(637)
imgRGB = imgThresh[:,:,::-1]
plt.title(f'BINARY_INV 1 = {thresh}')
plt.imshow(imgRGB)
plt.axis('off')

thresh =150
ret,imgThresh= cv.threshold(img,thresh,maxval,cv.THRESH_BINARY_INV)
plt.subplot(638)
imgRGB = imgThresh[:,:,::-1]
plt.title(f'BINARY_INV 2 = {thresh}')
plt.imshow(imgRGB)
plt.axis('off')

thresh =250
ret,imgThresh= cv.threshold(img,thresh,maxval,cv.THRESH_BINARY_INV)
plt.subplot(639)
imgRGB = imgThresh[:,:,::-1]
plt.title(f'BINARY_INV 3 = {thresh}')
plt.imshow(imgRGB)
plt.axis('off')

thresh =50
ret,imgThresh= cv.threshold(img,thresh,maxval,cv.THRESH_TRUNC)
plt.subplot(6,3,10)
imgRGB = imgThresh[:,:,::-1]
plt.title(f'THRESH_TRUNC 1 = {thresh}')
plt.imshow(imgRGB)
plt.axis('off')

thresh =150
ret,imgThresh= cv.threshold(img,thresh,maxval,cv.THRESH_TRUNC)
plt.subplot(6,3,11)
imgRGB = imgThresh[:,:,::-1]
plt.title(f'THRESH_TRUNC 2 = {thresh}')
plt.imshow(imgRGB)
plt.axis('off')

thresh =250
ret,imgThresh= cv.threshold(img,thresh,maxval,cv.THRESH_TRUNC)
plt.subplot(6,3,12)
imgRGB = imgThresh[:,:,::-1]
plt.title(f'THRESH_TRUNC 3 = {thresh}')
plt.imshow(imgRGB)
plt.axis('off')

thresh =50
ret,imgThresh= cv.threshold(img,thresh,maxval,cv.THRESH_TOZERO)
plt.subplot(6,3,13)
imgRGB = imgThresh[:,:,::-1]
plt.title(f'THRESH_TOZERO 1 = {thresh}')
plt.imshow(imgRGB)
plt.axis('off')

thresh =150
ret,imgThresh= cv.threshold(img,thresh,maxval,cv.THRESH_TOZERO)
plt.subplot(6,3,14)
imgRGB = imgThresh[:,:,::-1]
plt.title(f'THRESH_TOZERO 2 = {thresh}')
plt.imshow(imgRGB)
plt.axis('off')

thresh =250
ret,imgThresh= cv.threshold(img,thresh,maxval,cv.THRESH_TOZERO)
plt.subplot(6,3,15)
imgRGB = imgThresh[:,:,::-1]
plt.title(f'THRESH_TOZERO 3 = {thresh}')
plt.imshow(imgRGB)
plt.axis('off')

thresh =50
ret,imgThresh= cv.threshold(img,thresh,maxval,cv.THRESH_TOZERO_INV)
plt.subplot(6,3,16)
imgRGB = imgThresh[:,:,::-1]
plt.title(f'THRESH_TOZERO_INV 1 = {thresh}')
plt.imshow(imgRGB)
plt.axis('off')

thresh =150
ret,imgThresh= cv.threshold(img,thresh,maxval,cv.THRESH_TOZERO_INV)
plt.subplot(6,3,17)
imgRGB = imgThresh[:,:,::-1]
plt.title(f'THRESH_TOZERO_INV 2 = {thresh}')
plt.imshow(imgRGB)
plt.axis('off')

thresh =250
ret,imgThresh= cv.threshold(img,thresh,maxval,cv.THRESH_TOZERO_INV)
plt.subplot(6,3,18)
imgRGB = imgThresh[:,:,::-1]
plt.title(f'THRESH_TOZERO_INV 3 = {thresh}')
plt.imshow(imgRGB)
plt.axis('off')

plt.show()

# %% [markdown]
# 2. Apply the two adaptive threshold method to image ca[.ext]

# %%
import cv2 as cv
import matplotlib.pyplot as plt

imgPath = '../essential/assets/ca2.jpg'
img = cv.imread(imgPath)
img = img[:,:,::-1]
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

plt.figure(figsize=(15,10))

# original
plt.subplot(331)
plt.imshow(img)
plt.title('original')
plt.axis('off')

plt.subplot(332)
imgRGB = cv.cvtColor(img_gray,cv.COLOR_GRAY2RGB)
plt.imshow(imgRGB)
plt.title('gray')
plt.axis('off')

# 
maxval = 255
blockSize = 5
C = 2
thresh_img = cv.adaptiveThreshold(img_gray, maxval, cv.ADAPTIVE_THRESH_MEAN_C, cv.THRESH_BINARY, blockSize=blockSize, C=C)
# gray to RGB
thresh_img = cv.cvtColor(thresh_img, cv.COLOR_GRAY2RGB)
plt.subplot(334)
plt.imshow(thresh_img)
plt.title(f'ADAPTIVE_THRESH_MEAN_C, blockSize={blockSize}, C={C}')
plt.axis('off')

blockSize = 15
C = 2
thresh_img = cv.adaptiveThreshold(img_gray, maxval, cv.ADAPTIVE_THRESH_MEAN_C, cv.THRESH_BINARY, blockSize=blockSize, C=C)
# gray to RGB
thresh_img = cv.cvtColor(thresh_img, cv.COLOR_GRAY2RGB)
plt.subplot(335)
plt.imshow(thresh_img)
plt.title(f'ADAPTIVE_THRESH_MEAN_C, blockSize={blockSize}, C={C}')
plt.axis('off')

blockSize = 31
C = 2
thresh_img = cv.adaptiveThreshold(img_gray, maxval, cv.ADAPTIVE_THRESH_MEAN_C, cv.THRESH_BINARY, blockSize=blockSize, C=C)
# gray to RGB
thresh_img = cv.cvtColor(thresh_img, cv.COLOR_GRAY2RGB)
plt.subplot(336)
plt.imshow(thresh_img)
plt.title(f'ADAPTIVE_THRESH_MEAN_C, blockSize={blockSize}, C={C}')
plt.axis('off')

blockSize = 5
C = 2
thresh_img = cv.adaptiveThreshold(img_gray, maxval, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY, blockSize=blockSize, C=C)
# gray to RGB
thresh_img = cv.cvtColor(thresh_img, cv.COLOR_GRAY2RGB)
plt.subplot(337)
plt.imshow(thresh_img)
plt.title(f'ADAPTIVE_THRESH_GAUSSIAN_C, blockSize={blockSize}, C={C}')
plt.axis('off')

blockSize = 15
C = 2
thresh_img = cv.adaptiveThreshold(img_gray, maxval, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY, blockSize=blockSize, C=C)
# gray to RGB
thresh_img = cv.cvtColor(thresh_img, cv.COLOR_GRAY2RGB)
plt.subplot(338)
plt.imshow(thresh_img)
plt.title(f'ADAPTIVE_THRESH_GAUSSIAN_C, blockSize={blockSize}, C={C}')
plt.axis('off')

blockSize = 31
C = 2
thresh_img = cv.adaptiveThreshold(img_gray, maxval, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY, blockSize=blockSize, C=C)
# gray to RGB
thresh_img = cv.cvtColor(thresh_img, cv.COLOR_GRAY2RGB)
plt.subplot(339)
plt.imshow(thresh_img)
plt.title(f'ADAPTIVE_THRESH_GAUSSIAN_C, blockSize={blockSize}, C={C}')
plt.axis('off')


plt.tight_layout()

plt.show()

# %% [markdown]
# 3. Apply the bilateralFilter before appliying the two adaptive theshold method to image ca[.ext]

# %%
import cv2 as cv
import matplotlib.pyplot as plt

imgPath = '../essential/assets/ca2.jpg'
img = cv.imread(imgPath)
img = img[:,:,::-1]
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

plt.figure(figsize=(15,10))

# original
plt.subplot(331)
plt.imshow(img)
plt.title('original')
plt.axis('off')

plt.subplot(332)
imgRGB = cv.cvtColor(img_gray,cv.COLOR_GRAY2RGB)
plt.imshow(imgRGB)
plt.title('gray')
plt.axis('off')

# filtered gray
img_gray = cv.bilateralFilter(img_gray, 15, 25, 25)
plt.subplot(333)
imgRGB = cv.cvtColor(img_gray,cv.COLOR_GRAY2RGB)
plt.imshow(imgRGB)
plt.title('gray filtered')
plt.axis('off')

# 
maxval = 255
blockSize = 5
C = 2
thresh_img = cv.adaptiveThreshold(img_gray, maxval, cv.ADAPTIVE_THRESH_MEAN_C, cv.THRESH_BINARY, blockSize=blockSize, C=C)
# gray to RGB
thresh_img = cv.cvtColor(thresh_img, cv.COLOR_GRAY2RGB)
plt.subplot(334)
plt.imshow(thresh_img)
plt.title(f'ADAPTIVE_THRESH_MEAN_C, blockSize={blockSize}, C={C}')
plt.axis('off')

blockSize = 15
C = 2
thresh_img = cv.adaptiveThreshold(img_gray, maxval, cv.ADAPTIVE_THRESH_MEAN_C, cv.THRESH_BINARY, blockSize=blockSize, C=C)
# gray to RGB
thresh_img = cv.cvtColor(thresh_img, cv.COLOR_GRAY2RGB)
plt.subplot(335)
plt.imshow(thresh_img)
plt.title(f'ADAPTIVE_THRESH_MEAN_C, blockSize={blockSize}, C={C}')
plt.axis('off')

blockSize = 31
C = 2
thresh_img = cv.adaptiveThreshold(img_gray, maxval, cv.ADAPTIVE_THRESH_MEAN_C, cv.THRESH_BINARY, blockSize=blockSize, C=C)
# gray to RGB
thresh_img = cv.cvtColor(thresh_img, cv.COLOR_GRAY2RGB)
plt.subplot(336)
plt.imshow(thresh_img)
plt.title(f'ADAPTIVE_THRESH_MEAN_C, blockSize={blockSize}, C={C}')
plt.axis('off')

blockSize = 5
C = 2
thresh_img = cv.adaptiveThreshold(img_gray, maxval, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY, blockSize=blockSize, C=C)
# gray to RGB
thresh_img = cv.cvtColor(thresh_img, cv.COLOR_GRAY2RGB)
plt.subplot(337)
plt.imshow(thresh_img)
plt.title(f'ADAPTIVE_THRESH_GAUSSIAN_C, blockSize={blockSize}, C={C}')
plt.axis('off')

blockSize = 15
C = 2
thresh_img = cv.adaptiveThreshold(img_gray, maxval, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY, blockSize=blockSize, C=C)
# gray to RGB
thresh_img = cv.cvtColor(thresh_img, cv.COLOR_GRAY2RGB)
plt.subplot(338)
plt.imshow(thresh_img)
plt.title(f'ADAPTIVE_THRESH_GAUSSIAN_C, blockSize={blockSize}, C={C}')
plt.axis('off')

blockSize = 31
C = 2
thresh_img = cv.adaptiveThreshold(img_gray, maxval, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY, blockSize=blockSize, C=C)
# gray to RGB
thresh_img = cv.cvtColor(thresh_img, cv.COLOR_GRAY2RGB)
plt.subplot(339)
plt.imshow(thresh_img)
plt.title(f'ADAPTIVE_THRESH_GAUSSIAN_C, blockSize={blockSize}, C={C}')
plt.axis('off')


plt.tight_layout()

plt.show()
